# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from operator import add
from typing import List, TypedDict, Optional, Annotated, Dict

# The structure of the logs
class Log(TypedDict):
    id: str
    question: str
    docs: Optional[List]
    answer: str
    grade: Optional[int]
    grader: Optional[str]
    feedback: Optional[str]

# %% [markdown]
# ## Sub graphs
#
# Here is the failure analysis sub-graph, which uses `FailureAnalysisState`

# %%
from IPython.display import Image, display
from langgraph.graph import StateGraph, START, END

# Failure Analysis Sub-graph
class FailureAnalysisState(TypedDict):
    cleaned_logs: List[Log]
    failures: List[Log]
    fa_summary: str
    processed_logs: List[str]

class FailureAnalysisOutputState(TypedDict):    
    fa_summary: str
    processed_logs: List[str]

def get_failures(state):
    """ Get logs that contain a failure """
    cleaned_logs = state["cleaned_logs"]
    failures = [log for log in cleaned_logs if "grade" in log]
    return {"failures": failures}

def generate_summary(state):
    """ Generate summary of failures """    
    failures = state["failures"]
    # Add fxn: fa_summary = summarize(failures)
    fa_summary = "Poor quality retrieval of Chroma documentation."
    return {"fa_summary": fa_summary, "processed_logs": [f"failure-analysis-on-log-{failure['id']}" for failure in failures]}

fa_builder = StateGraph(input=FailureAnalysisState, output=FailureAnalysisOutputState)    
fa_builder.add_node("get_failures", get_failures)
fa_builder.add_node("generate_summary", generate_summary)
fa_builder.add_edge(START, "get_failures")
fa_builder.add_edge("get_failures", "generate_summary")
fa_builder.add_edge("generate_summary", END)

graph = fa_builder.compile()
display(Image(graph.get_graph().draw_mermaid_png()))
# Out:
# /tmp/ipykernel_322238/3138815976.py:28: LangGraphDeprecationWarning: Initializing StateGraph without state_schema is deprecated. Please pass in an explicit state_schema instead of just an input and output schema.
#   fa_builder = StateGraph(input=FailureAnalysisState, output=FailureAnalysisOutputState)
# ---------------------------------------------------------------------------
# PydanticUserError                         Traceback (most recent call last)
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/langchain_core/utils/pydantic.py:623, in create_model_v2(model_name, module_name, field_definitions, root)
#     622 try:
# --> 623     return _create_model_cached(model_name, **field_definitions)
#     624 except TypeError:
#     625     # something in field definitions is not hashable
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/langchain_core/utils/pydantic.py:479, in _create_model_cached(__model_name, **field_definitions)
#     474 @lru_cache(maxsize=256)
#     475 def _create_model_cached(
#     476     __model_name: str,
#     477     **field_definitions: Any,
#     478 ) -> type[BaseModel]:
# --> 479     return _create_model_base(
#     480         __model_name,
#     481         __config__=_SchemaConfig,
#     482         **_remap_field_definitions(field_definitions),
#     483     )
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/main.py:1600, in create_model(model_name, __config__, __doc__, __base__, __module__, __validators__, __cls_kwargs__, __slots__, **field_definitions)
#    1598 namespace.update(ns)
# -> 1600 return meta(
#    1601     model_name,
#    1602     resolved_bases,
#    1603     namespace,
#    1604     __pydantic_reset_parent_namespace__=False,
#    1605     _create_model_module=__module__,
#    1606     **kwds,
#    1607 )
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py:224, in ModelMetaclass.__new__(mcs, cls_name, bases, namespace, __pydantic_generic_metadata__, __pydantic_reset_parent_namespace__, _create_model_module, **kwargs)
#     222     set_default_hash_func(cls, bases)
# --> 224 complete_model_class(
#     225     cls,
#     226     cls_name,
#     227     config_wrapper,
#     228     raise_errors=False,
#     229     types_namespace=types_namespace,
#     230     create_model_module=_create_model_module,
#     231 )
#     233 # If this is placed before the complete_model_class call above,
#     234 # the generic computed fields return type is set to PydanticUndefined
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py:577, in complete_model_class(cls, cls_name, config_wrapper, raise_errors, types_namespace, create_model_module)
#     576 try:
# --> 577     schema = cls.__get_pydantic_core_schema__(cls, handler)
#     578 except PydanticUndefinedAnnotation as e:
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/main.py:671, in BaseModel.__get_pydantic_core_schema__(cls, source, handler)
#     669         return cls.__pydantic_core_schema__
# --> 671 return handler(source)
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_schema_generation_shared.py:83, in CallbackGetCoreSchemaHandler.__call__(self, source_type)
#      82 def __call__(self, source_type: Any, /) -> core_schema.CoreSchema:
# ---> 83     schema = self._handler(source_type)
#      84     ref = schema.get('ref')
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:655, in GenerateSchema.generate_schema(self, obj, from_dunder_get_core_schema)
#     654 if schema is None:
# --> 655     schema = self._generate_schema_inner(obj)
#     657 metadata_js_function = _extract_get_pydantic_json_schema(obj, schema)
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:924, in GenerateSchema._generate_schema_inner(self, obj)
#     923     with self.model_type_stack.push(obj):
# --> 924         return self._model_schema(obj)
#     926 if isinstance(obj, PydanticRecursiveRef):
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:739, in GenerateSchema._model_schema(self, cls)
#     737 else:
#     738     fields_schema: core_schema.CoreSchema = core_schema.model_fields_schema(
# --> 739         {k: self._generate_md_field_schema(k, v, decorators) for k, v in fields.items()},
#     740         computed_fields=[
#     741             self._computed_field_schema(d, decorators.field_serializers)
#     742             for d in computed_fields.values()
#     743         ],
#     744         extras_schema=extras_schema,
#     745         model_name=cls.__name__,
#     746     )
#     747     inner_schema = apply_validators(fields_schema, decorators.root_validators.values(), None)
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:739, in <dictcomp>(.0)
#     737 else:
#     738     fields_schema: core_schema.CoreSchema = core_schema.model_fields_schema(
# --> 739         {k: self._generate_md_field_schema(k, v, decorators) for k, v in fields.items()},
#     740         computed_fields=[
#     741             self._computed_field_schema(d, decorators.field_serializers)
#     742             for d in computed_fields.values()
#     743         ],
#     744         extras_schema=extras_schema,
#     745         model_name=cls.__name__,
#     746     )
#     747     inner_schema = apply_validators(fields_schema, decorators.root_validators.values(), None)
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:1115, in GenerateSchema._generate_md_field_schema(self, name, field_info, decorators)
#    1114 """Prepare a ModelField to represent a model field."""
# -> 1115 common_field = self._common_field_schema(name, field_info, decorators)
#    1116 return core_schema.model_field(
#    1117     common_field['schema'],
#    1118     serialization_exclude=common_field['serialization_exclude'],
#    (...)
#    1122     metadata=common_field['metadata'],
#    1123 )
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:1308, in GenerateSchema._common_field_schema(self, name, field_info, decorators)
#    1307     else:
# -> 1308         schema = self._apply_annotations(
#    1309             source_type,
#    1310             annotations + validators_from_decorators,
#    1311         )
#    1313 # This V1 compatibility shim should eventually be removed
#    1314 # push down any `each_item=True` validators
#    1315 # note that this won't work for any Annotated types that get wrapped by a function validator
#    1316 # but that's okay because that didn't exist in V1
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:2107, in GenerateSchema._apply_annotations(self, source_type, annotations, transform_inner_schema)
#    2103     get_inner_schema = self._get_wrapped_inner_schema(
#    2104         get_inner_schema, annotation, pydantic_js_annotation_functions
#    2105     )
# -> 2107 schema = get_inner_schema(source_type)
#    2108 if pydantic_js_annotation_functions:
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_schema_generation_shared.py:83, in CallbackGetCoreSchemaHandler.__call__(self, source_type)
#      82 def __call__(self, source_type: Any, /) -> core_schema.CoreSchema:
# ---> 83     schema = self._handler(source_type)
#      84     ref = schema.get('ref')
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:2088, in GenerateSchema._apply_annotations.<locals>.inner_handler(obj)
#    2087 if from_property is None:
# -> 2088     schema = self._generate_schema_inner(obj)
#    2089 else:
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:929, in GenerateSchema._generate_schema_inner(self, obj)
#     927     return core_schema.definition_reference_schema(schema_ref=obj.type_ref)
# --> 929 return self.match_type(obj)
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:1029, in GenerateSchema.match_type(self, obj)
#    1028 if origin is not None:
# -> 1029     return self._match_generic_type(obj, origin)
#    1031 res = self._get_prepare_pydantic_annotations_for_known_type(obj, ())
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:1062, in GenerateSchema._match_generic_type(self, obj, origin)
#    1061 elif origin in LIST_TYPES:
# -> 1062     return self._list_schema(self._get_first_arg_or_any(obj))
#    1063 elif origin in SET_TYPES:
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:431, in GenerateSchema._list_schema(self, items_type)
#     430 def _list_schema(self, items_type: Any) -> CoreSchema:
# --> 431     return core_schema.list_schema(self.generate_schema(items_type))
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:655, in GenerateSchema.generate_schema(self, obj, from_dunder_get_core_schema)
#     654 if schema is None:
# --> 655     schema = self._generate_schema_inner(obj)
#     657 metadata_js_function = _extract_get_pydantic_json_schema(obj, schema)
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:929, in GenerateSchema._generate_schema_inner(self, obj)
#     927     return core_schema.definition_reference_schema(schema_ref=obj.type_ref)
# --> 929 return self.match_type(obj)
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:999, in GenerateSchema.match_type(self, obj)
#     998 elif is_typeddict(obj):
# --> 999     return self._typed_dict_schema(obj, None)
#    1000 elif _typing_extra.is_namedtuple(obj):
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:1461, in GenerateSchema._typed_dict_schema(self, typed_dict_cls, origin)
#    1460 if not _SUPPORTS_TYPEDDICT and type(typed_dict_cls).__module__ == 'typing':
# -> 1461     raise PydanticUserError(
#    1462         'Please use `typing_extensions.TypedDict` instead of `typing.TypedDict` on Python < 3.12.',
#    1463         code='typed-dict-version',
#    1464     )
#    1466 try:
#
# PydanticUserError: Please use `typing_extensions.TypedDict` instead of `typing.TypedDict` on Python < 3.12.
#
# For further information visit https://errors.pydantic.dev/2.9/u/typed-dict-version
#
# During handling of the above exception, another exception occurred:
#
# PydanticUserError                         Traceback (most recent call last)
# Cell In[5], line 36
#      33 fa_builder.add_edge("generate_summary", END)
#      35 graph = fa_builder.compile()
# ---> 36 display(Image(graph.get_graph().draw_mermaid_png()))
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/langgraph/graph/graph.py:526, in CompiledGraph.get_graph(self, config, xray)
#     523 """Returns a drawable representation of the computation graph."""
#     524 graph = DrawableGraph()
#     525 start_nodes: dict[str, DrawableNode] = {
# --> 526     START: graph.add_node(self.get_input_schema(config), START)
#     527 }
#     528 end_nodes: dict[str, DrawableNode] = {}
#     529 if xray:
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/langgraph/graph/state.py:501, in CompiledStateGraph.get_input_schema(self, config)
#     498 def get_input_schema(
#     499     self, config: Optional[RunnableConfig] = None
#     500 ) -> type[BaseModel]:
# --> 501     return _get_schema(
#     502         typ=self.builder.input,
#     503         schemas=self.builder.schemas,
#     504         channels=self.builder.channels,
#     505         name=self.get_name("Input"),
#     506     )
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/langgraph/graph/state.py:816, in _get_schema(typ, schemas, channels, name)
#     811     return create_model(
#     812         name,
#     813         root=(channels[keys[0]].UpdateType, None),
#     814     )
#     815 else:
# --> 816     return create_model(
#     817         name,
#     818         field_definitions={
#     819             k: (
#     820                 channels[k].UpdateType,
#     821                 (
#     822                     get_field_default(
#     823                         k,
#     824                         channels[k].UpdateType,
#     825                         typ,
#     826                     )
#     827                 ),
#     828             )
#     829             for k in schemas[typ]
#     830             if k in channels and isinstance(channels[k], BaseChannel)
#     831         },
#     832     )
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/langgraph/utils/pydantic.py:24, in create_model(model_name, field_definitions, root)
#      20 try:
#      21     # for langchain-core >= 0.3.0
#      22     from langchain_core.utils.pydantic import create_model_v2
# ---> 24     return create_model_v2(
#      25         model_name,
#      26         field_definitions=field_definitions,
#      27         root=root,
#      28     )
#      29 except ImportError:
#      30     # for langchain-core < 0.3.0
#      31     from langchain_core.runnables.utils import create_model
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/langchain_core/utils/pydantic.py:626, in create_model_v2(model_name, module_name, field_definitions, root)
#     623     return _create_model_cached(model_name, **field_definitions)
#     624 except TypeError:
#     625     # something in field definitions is not hashable
# --> 626     return _create_model_base(
#     627         model_name,
#     628         __config__=_SchemaConfig,
#     629         **_remap_field_definitions(field_definitions),
#     630     )
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/main.py:1600, in create_model(model_name, __config__, __doc__, __base__, __module__, __validators__, __cls_kwargs__, __slots__, **field_definitions)
#    1597     ns['__orig_bases__'] = __base__
#    1598 namespace.update(ns)
# -> 1600 return meta(
#    1601     model_name,
#    1602     resolved_bases,
#    1603     namespace,
#    1604     __pydantic_reset_parent_namespace__=False,
#    1605     _create_model_module=__module__,
#    1606     **kwds,
#    1607 )
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py:224, in ModelMetaclass.__new__(mcs, cls_name, bases, namespace, __pydantic_generic_metadata__, __pydantic_reset_parent_namespace__, _create_model_module, **kwargs)
#     221 if config_wrapper.frozen and '__hash__' not in namespace:
#     222     set_default_hash_func(cls, bases)
# --> 224 complete_model_class(
#     225     cls,
#     226     cls_name,
#     227     config_wrapper,
#     228     raise_errors=False,
#     229     types_namespace=types_namespace,
#     230     create_model_module=_create_model_module,
#     231 )
#     233 # If this is placed before the complete_model_class call above,
#     234 # the generic computed fields return type is set to PydanticUndefined
#     235 cls.model_computed_fields = {k: v.info for k, v in cls.__pydantic_decorators__.computed_fields.items()}
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py:577, in complete_model_class(cls, cls_name, config_wrapper, raise_errors, types_namespace, create_model_module)
#     574     return False
#     576 try:
# --> 577     schema = cls.__get_pydantic_core_schema__(cls, handler)
#     578 except PydanticUndefinedAnnotation as e:
#     579     if raise_errors:
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/main.py:671, in BaseModel.__get_pydantic_core_schema__(cls, source, handler)
#     668     if not cls.__pydantic_generic_metadata__['origin']:
#     669         return cls.__pydantic_core_schema__
# --> 671 return handler(source)
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_schema_generation_shared.py:83, in CallbackGetCoreSchemaHandler.__call__(self, source_type)
#      82 def __call__(self, source_type: Any, /) -> core_schema.CoreSchema:
# ---> 83     schema = self._handler(source_type)
#      84     ref = schema.get('ref')
#      85     if self._ref_mode == 'to-def':
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:655, in GenerateSchema.generate_schema(self, obj, from_dunder_get_core_schema)
#     652         schema = from_property
#     654 if schema is None:
# --> 655     schema = self._generate_schema_inner(obj)
#     657 metadata_js_function = _extract_get_pydantic_json_schema(obj, schema)
#     658 if metadata_js_function is not None:
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:924, in GenerateSchema._generate_schema_inner(self, obj)
#     922 if lenient_issubclass(obj, BaseModel):
#     923     with self.model_type_stack.push(obj):
# --> 924         return self._model_schema(obj)
#     926 if isinstance(obj, PydanticRecursiveRef):
#     927     return core_schema.definition_reference_schema(schema_ref=obj.type_ref)
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:739, in GenerateSchema._model_schema(self, cls)
#     727     model_schema = core_schema.model_schema(
#     728         cls,
#     729         inner_schema,
#    (...)
#     735         metadata=metadata,
#     736     )
#     737 else:
#     738     fields_schema: core_schema.CoreSchema = core_schema.model_fields_schema(
# --> 739         {k: self._generate_md_field_schema(k, v, decorators) for k, v in fields.items()},
#     740         computed_fields=[
#     741             self._computed_field_schema(d, decorators.field_serializers)
#     742             for d in computed_fields.values()
#     743         ],
#     744         extras_schema=extras_schema,
#     745         model_name=cls.__name__,
#     746     )
#     747     inner_schema = apply_validators(fields_schema, decorators.root_validators.values(), None)
#     748     new_inner_schema = define_expected_missing_refs(inner_schema, recursively_defined_type_refs())
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:739, in <dictcomp>(.0)
#     727     model_schema = core_schema.model_schema(
#     728         cls,
#     729         inner_schema,
#    (...)
#     735         metadata=metadata,
#     736     )
#     737 else:
#     738     fields_schema: core_schema.CoreSchema = core_schema.model_fields_schema(
# --> 739         {k: self._generate_md_field_schema(k, v, decorators) for k, v in fields.items()},
#     740         computed_fields=[
#     741             self._computed_field_schema(d, decorators.field_serializers)
#     742             for d in computed_fields.values()
#     743         ],
#     744         extras_schema=extras_schema,
#     745         model_name=cls.__name__,
#     746     )
#     747     inner_schema = apply_validators(fields_schema, decorators.root_validators.values(), None)
#     748     new_inner_schema = define_expected_missing_refs(inner_schema, recursively_defined_type_refs())
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:1115, in GenerateSchema._generate_md_field_schema(self, name, field_info, decorators)
#    1108 def _generate_md_field_schema(
#    1109     self,
#    1110     name: str,
#    1111     field_info: FieldInfo,
#    1112     decorators: DecoratorInfos,
#    1113 ) -> core_schema.ModelField:
#    1114     """Prepare a ModelField to represent a model field."""
# -> 1115     common_field = self._common_field_schema(name, field_info, decorators)
#    1116     return core_schema.model_field(
#    1117         common_field['schema'],
#    1118         serialization_exclude=common_field['serialization_exclude'],
#    (...)
#    1122         metadata=common_field['metadata'],
#    1123     )
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:1308, in GenerateSchema._common_field_schema(self, name, field_info, decorators)
#    1304         schema = self._apply_annotations(
#    1305             source_type, annotations + validators_from_decorators, transform_inner_schema=set_discriminator
#    1306         )
#    1307     else:
# -> 1308         schema = self._apply_annotations(
#    1309             source_type,
#    1310             annotations + validators_from_decorators,
#    1311         )
#    1313 # This V1 compatibility shim should eventually be removed
#    1314 # push down any `each_item=True` validators
#    1315 # note that this won't work for any Annotated types that get wrapped by a function validator
#    1316 # but that's okay because that didn't exist in V1
#    1317 this_field_validators = filter_field_decorator_info_by_field(decorators.validators.values(), name)
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:2107, in GenerateSchema._apply_annotations(self, source_type, annotations, transform_inner_schema)
#    2102         continue
#    2103     get_inner_schema = self._get_wrapped_inner_schema(
#    2104         get_inner_schema, annotation, pydantic_js_annotation_functions
#    2105     )
# -> 2107 schema = get_inner_schema(source_type)
#    2108 if pydantic_js_annotation_functions:
#    2109     metadata = CoreMetadataHandler(schema).metadata
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_schema_generation_shared.py:83, in CallbackGetCoreSchemaHandler.__call__(self, source_type)
#      82 def __call__(self, source_type: Any, /) -> core_schema.CoreSchema:
# ---> 83     schema = self._handler(source_type)
#      84     ref = schema.get('ref')
#      85     if self._ref_mode == 'to-def':
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:2088, in GenerateSchema._apply_annotations.<locals>.inner_handler(obj)
#    2086 from_property = self._generate_schema_from_property(obj, source_type)
#    2087 if from_property is None:
# -> 2088     schema = self._generate_schema_inner(obj)
#    2089 else:
#    2090     schema = from_property
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:929, in GenerateSchema._generate_schema_inner(self, obj)
#     926 if isinstance(obj, PydanticRecursiveRef):
#     927     return core_schema.definition_reference_schema(schema_ref=obj.type_ref)
# --> 929 return self.match_type(obj)
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:1029, in GenerateSchema.match_type(self, obj)
#    1027 origin = get_origin(obj)
#    1028 if origin is not None:
# -> 1029     return self._match_generic_type(obj, origin)
#    1031 res = self._get_prepare_pydantic_annotations_for_known_type(obj, ())
#    1032 if res is not None:
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:1062, in GenerateSchema._match_generic_type(self, obj, origin)
#    1060     return self._tuple_schema(obj)
#    1061 elif origin in LIST_TYPES:
# -> 1062     return self._list_schema(self._get_first_arg_or_any(obj))
#    1063 elif origin in SET_TYPES:
#    1064     return self._set_schema(self._get_first_arg_or_any(obj))
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:431, in GenerateSchema._list_schema(self, items_type)
#     430 def _list_schema(self, items_type: Any) -> CoreSchema:
# --> 431     return core_schema.list_schema(self.generate_schema(items_type))
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:655, in GenerateSchema.generate_schema(self, obj, from_dunder_get_core_schema)
#     652         schema = from_property
#     654 if schema is None:
# --> 655     schema = self._generate_schema_inner(obj)
#     657 metadata_js_function = _extract_get_pydantic_json_schema(obj, schema)
#     658 if metadata_js_function is not None:
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:929, in GenerateSchema._generate_schema_inner(self, obj)
#     926 if isinstance(obj, PydanticRecursiveRef):
#     927     return core_schema.definition_reference_schema(schema_ref=obj.type_ref)
# --> 929 return self.match_type(obj)
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:999, in GenerateSchema.match_type(self, obj)
#     997     return self._literal_schema(obj)
#     998 elif is_typeddict(obj):
# --> 999     return self._typed_dict_schema(obj, None)
#    1000 elif _typing_extra.is_namedtuple(obj):
#    1001     return self._namedtuple_schema(obj, None)
#
# File ~/code/github/python/langchain-academy/lc-academy-env/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:1461, in GenerateSchema._typed_dict_schema(self, typed_dict_cls, origin)
#    1458     typed_dict_cls = origin
#    1460 if not _SUPPORTS_TYPEDDICT and type(typed_dict_cls).__module__ == 'typing':
# -> 1461     raise PydanticUserError(
#    1462         'Please use `typing_extensions.TypedDict` instead of `typing.TypedDict` on Python < 3.12.',
#    1463         code='typed-dict-version',
#    1464     )
#    1466 try:
#    1467     config: ConfigDict | None = get_attribute_from_bases(typed_dict_cls, '__pydantic_config__')
#
# PydanticUserError: Please use `typing_extensions.TypedDict` instead of `typing.TypedDict` on Python < 3.12.
#
# For further information visit https://errors.pydantic.dev/2.9/u/typed-dict-version
